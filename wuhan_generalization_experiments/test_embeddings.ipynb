# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Simple visulalization of the adj mats.

af2_adg = np.load("/mnt/ncshare/ozkilim/covid/data_release_paper/wuhan_generalization_experements/embeddings/omicron_ba2_adj_mat_encoding.npy")
# ohe = np.load("/mnt/ncshare/ozkilim/covid/data_release_paper/wuhan_generalization_experements/embeddings/omicron_ba2_one_hot_encoding.npy")
af2_adg = af2_adg[0,:-2]

af2_adg = af2_adg.reshape((201, 201))

fig = plt.figure()
plt.imshow(af2_adg)

clb=plt.colorbar()
clb.ax.tick_params(labelsize=13) 
clb.ax.set_title('Å',fontsize=15)

# plt.colorbar()
plt.axis('off')
plt.show()
fig.savefig("../reasults_figs/adj_mat.png",bbox_inches='tight',facecolor="white")
